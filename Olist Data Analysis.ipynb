# %% [markdown]
# ## Import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Load the datasets

# %%
customers_df = pd.read_csv(r"olist_customers_dataset.csv")
geolocation_df = pd.read_csv(r"olist_geolocation_dataset.csv")
order_items_df = pd.read_csv(r"olist_order_items_dataset.csv")
order_payment_df = pd.read_csv(r"olist_order_payments_dataset.csv")
order_reviews_df = pd.read_csv(r"olist_order_reviews_dataset.csv")
orders_df = pd.read_csv(r"olist_orders_dataset.csv")
products_df = pd.read_csv(r"olist_products_dataset.csv")
sellers_df = pd.read_csv(r"olist_sellers_dataset.csv")
category_df = pd.read_csv(r"product_category_name_translation.csv")

# %% [markdown]
# ## Have a look at the datas being read

# %%
customers_df
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
geolocation_df
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %%
order_items_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
order_payment_df
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
order_reviews_df
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99995  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99996  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99997  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99998  be360f18f5df1e0541061c87021e6d93  f8bd3f2000c28c5342fedeb5e50f2e75
# 99999  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
orders_df
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
products_df
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
sellers_df
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
category_df
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %% [markdown]
# ## Business Case 1: What is the total revenue generated by Olist, and how has it changed over time?

# %%
order_payment_df
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %% [markdown]
# #### This isn't enough to answer the question, so we should try to merge data from other loaded data

# %% [markdown]
# ## Merge the order_payments_df with orders_df on order_id and assign it to a variable data which we will use henceforth has it contains more data

# %%
data=order_payment_df.merge(orders_df,on='order_id', how='left')

# %% [markdown]
# ## Check for missing values in the data variable

# %%
data.isnull().sum()
# Out:
# order_id                            0
# payment_sequential                  0
# payment_type                        0
# payment_installments                0
# payment_value                       0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 175
# order_delivered_carrier_date     1888
# order_delivered_customer_date    3132
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# #### The missing values are dates, let's neglect them for the time being

# %% [markdown]
# ## Get more insights on the data variable

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103886 entries, 0 to 103885
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       103886 non-null  object
#  1   payment_sequential             103886 non-null  int64
#  2   payment_type                   103886 non-null  object
#  3   payment_installments           103886 non-null  int64
#  4   payment_value                  103886 non-null  float64
#  5   customer_id                    103886 non-null  object
#  6   order_status                   103886 non-null  object
#  7   order_purchase_timestamp       103886 non-null  object
#  8   order_approved_at              103711 non-null  object
#  9   order_delivered_carrier_date   101998 non-null  object
#  10  order_delivered_customer_date  100754 non-null  object
#  11  order_estimated_delivery_date  103886 non-null  object
# ...

# %% [markdown]
# #### In data, some columns which are supposed to be of datatype datetime are of datatype object, lets convert them to the supposeful right datatype

# %%
data['order_purchase_timestamp']=data['order_purchase_timestamp'].astype('datetime64')
data['order_approved_at']=data['order_approved_at'].astype('datetime64')
data['order_delivered_carrier_date']=data['order_delivered_carrier_date'].astype('datetime64')
data['order_delivered_customer_date']=data['order_delivered_customer_date'].astype('datetime64')
data['order_estimated_delivery_date']=data['order_estimated_delivery_date'].astype('datetime64')

# %% [markdown]
# ## Let's confirm the changes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103886 entries, 0 to 103885
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       103886 non-null  object
#  1   payment_sequential             103886 non-null  int64
#  2   payment_type                   103886 non-null  object
#  3   payment_installments           103886 non-null  int64
#  4   payment_value                  103886 non-null  float64
#  5   customer_id                    103886 non-null  object
#  6   order_status                   103886 non-null  object
#  7   order_purchase_timestamp       103886 non-null  datetime64[ns]
#  8   order_approved_at              103711 non-null  datetime64[ns]
#  9   order_delivered_carrier_date   101998 non-null  datetime64[ns]
#  10  order_delivered_customer_date  100754 non-null  datetime64[ns]
# ...

# %% [markdown]
# ## Group data by month and year and getting the monthly payment_value

# %%
monthly_revenue=data.groupby(pd.Grouper(key='order_purchase_timestamp',freq='MS'))['payment_value'].sum().reset_index()

# %%
monthly_revenue
# Out:
#    order_purchase_timestamp  payment_value
# 0                2016-09-01         252.24
# 1                2016-10-01       59090.48
# 2                2016-11-01           0.00
# 3                2016-12-01          19.62
# 4                2017-01-01      138488.04
# 5                2017-02-01      291908.01
# 6                2017-03-01      449863.60
# 7                2017-04-01      417788.03
# 8                2017-05-01      592918.82
# 9                2017-06-01      511276.38
# 10               2017-07-01      592382.92
# 11               2017-08-01      674396.32
# 12               2017-09-01      727762.45
# 13               2017-10-01      779677.88
# 14               2017-11-01     1194882.80
# 15               2017-12-01      878401.48
# 16               2018-01-01     1115004.18
# 17               2018-02-01      992463.34
# 18               2018-03-01     1159652.12
# 19               2018-04-01     1160785.48
# 20               2018-05-01     1153982.15
# ...

# %% [markdown]
# ## Rename Columns

# %%
monthly_revenue.rename(columns={'order_purchase_timestamp':'month','payment_value':'revenue'}, inplace=True)

# %% [markdown]
# ## Check the changes

# %%
monthly_revenue
# Out:
#         month     revenue
# 0  2016-09-01      252.24
# 1  2016-10-01    59090.48
# 2  2016-11-01        0.00
# 3  2016-12-01       19.62
# 4  2017-01-01   138488.04
# 5  2017-02-01   291908.01
# 6  2017-03-01   449863.60
# 7  2017-04-01   417788.03
# 8  2017-05-01   592918.82
# 9  2017-06-01   511276.38
# 10 2017-07-01   592382.92
# 11 2017-08-01   674396.32
# 12 2017-09-01   727762.45
# 13 2017-10-01   779677.88
# 14 2017-11-01  1194882.80
# 15 2017-12-01   878401.48
# 16 2018-01-01  1115004.18
# 17 2018-02-01   992463.34
# 18 2018-03-01  1159652.12
# 19 2018-04-01  1160785.48
# 20 2018-05-01  1153982.15
# 21 2018-06-01  1023880.50
# 22 2018-07-01  1066540.75
# 23 2018-08-01  1022425.32
# 24 2018-09-01     4439.54
# 25 2018-10-01      589.67

# %% [markdown]
# ## Get the sum of the revenue column. Which is the total Revenue generated by Olist

# %%
monthly_revenue.revenue.sum()
# Out:
# 16008872.12

# %% [markdown]
# ## Plot how the monthly revenue changes with time

# %%
plt.figure(figsize=(12,4))
plt.plot(monthly_revenue['month'], monthly_revenue['revenue'],marker='o')
plt.title('Revenue By Month')
plt.xlabel('Month and Year')
plt.ylabel('Total Revenue (Million)')

plt.show()

# %% [markdown]
# ## Business Case 2: How many orders were placed on Olist, and how does this vary by month or season?

# %% [markdown]
# ## Let's have a new glimpse on the data

# %%
data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %% [markdown]
# #### There is sufficient data to answer the question

# %% [markdown]
# ## Get the unique order_id for every order in each month(to handle cases of repeated order_id), apply len function to count it creating a new column for the total orders for that month and renaming the colums

# %%
monthly_order=data.groupby(pd.Grouper(key='order_purchase_timestamp',freq='MS'))['order_id'].unique().reset_index()
monthly_order['total_orders']=monthly_order['order_id'].apply(len)
monthly_order.rename(columns={'order_purchase_timestamp':'month'})
# Out:
#         month                                           order_id  total_orders
# 0  2016-09-01  [2e7a8482f6fb09756ca50c10d7bfc047, e5fa5a72109...             3
# 1  2016-10-01  [71303d7e93b399f5bcd537d124c0bcfa, 3b697a20d9e...           324
# 2  2016-11-01                                                 []             0
# 3  2016-12-01                 [bd50a7fe9fd97ea4b7663031a319e150]             1
# 4  2017-01-01  [ec7a019261fce44180373d45b442d78f, b95a0a8bd30...           800
# 5  2017-02-01  [df8c077268f7f3baaac0892eb3143642, 0e659173ebf...          1780
# 6  2017-03-01  [7d0a7957897551b77224fc297e8f6046, 31a606477f1...          2682
# 7  2017-04-01  [9d343b43e2a3552fdfaff5ad21a9af61, e49d81cefb4...          2404
# 8  2017-05-01  [c9dbbd1ca9411200390b157cb42ea79a, 55dfff244bc...          3700
# 9  2017-06-01  [69de6dd68bcaad14dda6d5e33e45bf98, 8d80eb399a6...          3245
# 10 2017-07-01  [0560d129c1357ea719aab1cf2cd4f03b, cec9f2d0123...          4026
# ...

# %% [markdown]
# ## Calculate the total_orders

# %%
monthly_order.total_orders.sum()
# Out:
# 99440

# %% [markdown]
# ## Make a plot showing how orders changes by month

# %%
plt.figure(figsize=(12,4))
plt.plot(monthly_order['order_purchase_timestamp'], monthly_order['total_orders'],marker='o')
plt.title('No. of Orders by Month')
plt.xlabel('Month and Year')
plt.ylabel('No. of orders')

plt.show()

# %% [markdown]
# ## Business Case 3: What are the most popular product categories on Olist, and how do their sales volumes compare to each other?

# %% [markdown]
# ## Have a glimpse at data

# %%
data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %% [markdown]
# #### There is no information related to product category on data, so we need more information from other datasets we read earlier

# %% [markdown]
# ## Inspect order_items_df while sorting the values

# %%
order_items_df.sort_values('order_id').iloc[:50,:]
# Out:
#                             order_id  order_item_id  \
# 0   00010242fe8c5a6d1ba2dd792cb16214              1
# 1   00018f77f2f0320c557190d7a144bdd3              1
# 2   000229ec398224ef6ca0657da4fc703e              1
# 3   00024acbcdf0a6daa1e931b038114c75              1
# 4   00042b26cf59d7ce69dfabb4e55b4fd9              1
# 5   00048cc3ae777c65dbb7d2a0634bc1ea              1
# 6   00054e8431b9d7675808bcb819fb4a32              1
# 7   000576fe39319847cbb9d288c5617fa6              1
# 8   0005a1a1728c9d785b8e2b08b904576c              1
# 9   0005f50442cb953dcd1d21e1fb923495              1
# 10  00061f2a7bc09da83e415a52dc8a4af1              1
# 11  00063b381e2406b52ad429470734ebd5              1
# 12  0006ec9db01a64e59a68b2c340bf65a7              1
# 13  0008288aa423d2a3f00fcb17cd7d8719              1
# 14  0008288aa423d2a3f00fcb17cd7d8719              2
# 15  0009792311464db532ff765bf7b182ae              1
# 16  0009c9a17f916a706d71784483a5d643              1
# ...

# %% [markdown]
# #### It was noticed that the order_items_df has order_item_id and in some cases they differ while all other columns remain the same, it looks like repetition but we don't know what else we will come across it may come in andy, but to avoid working with multiple row with same data, we filter the merge by order_item_id==1 and merge

# %%
data=data.merge(order_items_df[order_items_df.order_item_id==1], on='order_id',how='left')
data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %% [markdown]
# ## Check for missing values

# %%
data.isnull().sum()
# Out:
# order_id                            0
# payment_sequential                  0
# payment_type                        0
# payment_installments                0
# payment_value                       0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 175
# order_delivered_carrier_date     1888
# order_delivered_customer_date    3132
# order_estimated_delivery_date       0
# order_item_id                     830
# product_id                        830
# seller_id                         830
# shipping_limit_date               830
# price                             830
# freight_value                     830
# dtype: int64

# %% [markdown]
# #### There are a couple of missing values, why???

# %% [markdown]
# ## Check the rows of the datas in data with nan in product_id

# %%
data[data.product_id.isnull()]
# Out:
#                                 order_id  payment_sequential payment_type  \
# 68      947e9c6bfd83a06953c420ef92d3da6e                   1      voucher
# 235     f86d7bc39aab05299691322044b63bb2                   1      voucher
# 259     90eaac01afdf4e531a70ad869e092c75                   1  credit_card
# 720     fe87d4b944748f63ca5ed22cc55b6fb6                   1   debit_card
# 1014    4a42846a6eed9d15714fe30181399f2a                   1  credit_card
# ...                                  ...                 ...          ...
# 103718  fc20b8e282da6f3fbcdd3a3cedecb723                   1  credit_card
# 103728  92fca7ed7b7df4695007bd7f227e3333                   1  credit_card
# 103766  b17fd4c033b06e8d888de8ea6105ef9d                   1  credit_card
# 103807  974f9f87a3bad01b2ac72fe987505e9b                   1  credit_card
# 103880  7159096c5aa9be77f7f0c26c01ee9793                   1  credit_card
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %% [markdown]
# ## Check order_items_df for more insights

# %%
order_items_df[order_items_df.order_id=='947e9c6bfd83a06953c420ef92d3da6e']
# Out:
# Empty DataFrame
# Columns: [order_id, order_item_id, product_id, seller_id, shipping_limit_date, price, freight_value]
# Index: []

# %% [markdown]
# #### It appears that for element with the missing value, information on their order_id was missing in order_items_df, let's work with it like that

# %% [markdown]
# ## Let's have a look at data again

# %%
data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %% [markdown]
# #### There's still not enough information to answer the question, lets merge more data

# %%
products_df
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %% [markdown]
# ## Merge data with products_df on product_id and enable max display on column so we can see all columns

# %%
data=data.merge(products_df,on='product_id',how='left')
pd.set_option('display.max_columns',None)
data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %% [markdown]
# ## Check for null values in data

# %%
data.isnull().sum()
# Out:
# order_id                            0
# payment_sequential                  0
# payment_type                        0
# payment_installments                0
# payment_value                       0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 175
# order_delivered_carrier_date     1888
# order_delivered_customer_date    3132
# order_estimated_delivery_date       0
# order_item_id                     830
# product_id                        830
# seller_id                         830
# shipping_limit_date               830
# price                             830
# freight_value                     830
# product_category_name            2331
# product_name_lenght              2331
# product_description_lenght       2331
# product_photos_qty               2331
# product_weight_g                  848
# product_length_cm                 848
# product_height_cm                 848
# ...

# %% [markdown]
# #### There are many missing values, let's try to understand why.

# %% [markdown]
# ## Check data where product_category_name was missing

# %%
data[data.product_category_name.isnull()]
# Out:
#                                 order_id  payment_sequential payment_type  \
# 68      947e9c6bfd83a06953c420ef92d3da6e                   1      voucher
# 100     96de2b7f7f3c401fbee3eef068376da6                   1       boleto
# 127     f51e3c7f79d1e2c076acbb6af1588b95                   1  credit_card
# 203     52636dd3c039f62169b0eb724af63047                   1  credit_card
# 235     f86d7bc39aab05299691322044b63bb2                   1      voucher
# ...                                  ...                 ...          ...
# 103776  0e631eca89e976f885d1ef7f7a4a4698                   1  credit_card
# 103807  974f9f87a3bad01b2ac72fe987505e9b                   1  credit_card
# 103808  312384a598132f165ae6f58bc210f8fb                   1       boleto
# 103826  1ad1ca4550bd6dbd299d8538a86e5400                   1  credit_card
# 103880  7159096c5aa9be77f7f0c26c01ee9793                   1  credit_card
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %% [markdown]
# #### We got way too much empty values! Why?
# #### Let's try to understand

# %%
products_df.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# #### Now we know why, the product_df has a lot of missing values from the data. Our company should learn to collect data better lol!

# %% [markdown]
# ## Merge the data with category_df

# %%
data=data.merge(category_df,on='product_category_name',how='left')
data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %% [markdown]
# ## Check for missing values

# %%
data.isnull().sum()
# Out:
# order_id                            0
# payment_sequential                  0
# payment_type                        0
# payment_installments                0
# payment_value                       0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 175
# order_delivered_carrier_date     1888
# order_delivered_customer_date    3132
# order_estimated_delivery_date       0
# order_item_id                     830
# product_id                        830
# seller_id                         830
# shipping_limit_date               830
# price                             830
# freight_value                     830
# product_category_name            2331
# product_name_lenght              2331
# product_description_lenght       2331
# product_photos_qty               2331
# product_weight_g                  848
# product_length_cm                 848
# product_height_cm                 848
# ...

# %% [markdown]
# ## group products by number of times they've been purchased

# %%
purchase_by_product_category=data[['product_category_name_english','payment_value']].groupby('product_category_name_english').count().reset_index()
purchase_by_product_category.rename(columns={'payment_value':'number of times purchased'}, inplace=True)
purchase_by_product_category
# Out:
#    product_category_name_english  number of times purchased
# 0     agro_industry_and_commerce                        211
# 1               air_conditioning                        256
# 2                            art                        208
# 3          arts_and_craftmanship                         22
# 4                          audio                        362
# ..                           ...                        ...
# 66                    stationery                       2384
# 67        tablets_printing_image                         81
# 68                     telephony                       4346
# 69                          toys                       4007
# 70                 watches_gifts                       5805
#
# [71 rows x 2 columns]

# %% [markdown]
# ## Sort it in descending order

# %%
purchase_by_product_category=purchase_by_product_category.sort_values('number of times purchased', ascending=False).reset_index(drop=True)

# %% [markdown]
# ## Get the product category with highest sales volume

# %%
purchase_by_product_category.iloc[:1,:]
# Out:
#   product_category_name_english  number of times purchased
# 0                bed_bath_table                       9899

# %% [markdown]
# ## Make a plot comparing the sales volume of different product category

# %%
plt.barh(purchase_by_product_category['product_category_name_english'][:12],\
         purchase_by_product_category['number of times purchased'][:12])
plt.title('Top 12 Product Category ')
plt.ylabel('Category')
plt.xlabel('No. of Sales')
plt.show()

# %% [markdown]
# ## 4: What is the average order value (AOV) on Olist, and how does this vary by product category or payment method?

# %%
data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %% [markdown]
# ## Group by payment type and get to the sum of total revenue for each payment type

# %%
revenue_by_payment_type=data[['payment_type','payment_value']].groupby('payment_type').sum()
revenue_by_payment_type.rename(columns={'payment_value':'total_revenue'},inplace=True)
revenue_by_payment_type
# Out:
#               total_revenue
# payment_type
# boleto           2869361.27
# credit_card     12542084.19
# debit_card        217989.79
# not_defined            0.00
# voucher           379436.87

# %% [markdown]
# ## Group by payment type and get the number of time a purchase has been made with that payment type

# %%
no_of_purchase_by_payment_type=data[['payment_type','payment_value']].groupby('payment_type').count()
no_of_purchase_by_payment_type.rename(columns={'payment_value':'number_of_purchases'},inplace=True)
no_of_purchase_by_payment_type
# Out:
#               number_of_purchases
# payment_type
# boleto                      19784
# credit_card                 76795
# debit_card                   1529
# not_defined                     3
# voucher                      5775

# %% [markdown]
# ## Create a variable average_order_value thats stores the average order value of each payment type, to do this, we merge the previous two groupings we made and divide the total_revenue by number of purchases

# %%
average_order_value=revenue_by_payment_type.merge(no_of_purchase_by_payment_type, on='payment_type')
average_order_value['aov']=round(average_order_value['total_revenue']/average_order_value['number_of_purchases'],2)
average_order_value.reset_index(inplace=True)

# %% [markdown]
# ## Let's see the average_order_value dataframe

# %%
average_order_value
# Out:
#   payment_type  total_revenue  number_of_purchases     aov
# 0       boleto     2869361.27                19784  145.03
# 1  credit_card    12542084.19                76795  163.32
# 2   debit_card      217989.79                 1529  142.57
# 3  not_defined           0.00                    3    0.00
# 4      voucher      379436.87                 5775   65.70

# %% [markdown]
# ## Drop row 3 [row with payment type 'not_defined']

# %%
average_order_value=average_order_value.drop(3)
average_order_value
# Out:
#   payment_type  total_revenue  number_of_purchases     aov
# 0       boleto     2869361.27                19784  145.03
# 1  credit_card    12542084.19                76795  163.32
# 2   debit_card      217989.79                 1529  142.57
# 4      voucher      379436.87                 5775   65.70

# %% [markdown]
# ## Let's view it in a bar graph

# %%
plt.bar(average_order_value['payment_type'],average_order_value['aov'])
plt.title('Average Order Value for Payment Type')
plt.xlabel('Payment Type')
plt.ylabel('Average Order Value (AOV)')
plt.show()

# %% [markdown]
# ## 5: How many sellers are active on Olist, and how does this number change over time?

# %%
data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %% [markdown]
# ## Calculate the number of sellers (unique) that have sold on Olist

# %%
f'There are {len(data.seller_id.unique())} active sellers on Olist'
# Out:
# 'There are 3089 active sellers on Olist'

# %% [markdown]
# ## check for missing values in data

# %%
data.isnull().sum()
# Out:
# order_id                            0
# payment_sequential                  0
# payment_type                        0
# payment_installments                0
# payment_value                       0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 175
# order_delivered_carrier_date     1888
# order_delivered_customer_date    3132
# order_estimated_delivery_date       0
# order_item_id                     830
# product_id                        830
# seller_id                         830
# shipping_limit_date               830
# price                             830
# freight_value                     830
# product_category_name            2331
# product_name_lenght              2331
# product_description_lenght       2331
# product_photos_qty               2331
# product_weight_g                  848
# product_length_cm                 848
# product_height_cm                 848
# ...

# %% [markdown]
# ## group data by number of active sellers per month

# %%
sellers_by_month=data.groupby(pd.Grouper(key='order_purchase_timestamp',freq='MS')).agg({'seller_id':'unique'})
sellers_by_month=sellers_by_month.seller_id.apply(len)
sellers_by_month
# Out:
# order_purchase_timestamp
# 2016-09-01       3
# 2016-10-01     142
# 2016-11-01       0
# 2016-12-01       1
# 2017-01-01     226
# 2017-02-01     427
# 2017-03-01     498
# 2017-04-01     506
# 2017-05-01     581
# 2017-06-01     538
# 2017-07-01     602
# 2017-08-01     706
# 2017-09-01     731
# 2017-10-01     772
# 2017-11-01     963
# 2017-12-01     859
# 2018-01-01     964
# 2018-02-01     946
# 2018-03-01     988
# 2018-04-01    1119
# 2018-05-01    1107
# 2018-06-01    1164
# 2018-07-01    1255
# 2018-08-01    1268
# 2018-09-01       2
# 2018-10-01       1
# Freq: MS, Name: seller_id, dtype: int64

# %% [markdown]
# ## Make a plot for easier visualisation

# %%
plt.figure(figsize=(12,4))
sellers_by_month.plot(marker='o')
plt.title('No. of Active Sellers by Month')
plt.xlabel('Month and Year')
plt.ylabel('No. of Active Sellers')

plt.show()

# %% [markdown]
# ## Calculate no. of active sellers per year

# %%
sellers_by_year=data.groupby(pd.Grouper(key='order_purchase_timestamp',freq='A')).agg({'seller_id':'unique'})
sellers_by_year=sellers_by_year.seller_id.apply(len)
sellers_by_year
# Out:
# order_purchase_timestamp
# 2016-12-31     144
# 2017-12-31    1784
# 2018-12-31    2376
# Freq: A-DEC, Name: seller_id, dtype: int64

# %% [markdown]
# ## 6: What is the distribution of seller ratings on Olist, and how does this impact sales performance?

# %%
data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %%
order_reviews_df
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99995  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99996  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99997  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99998  be360f18f5df1e0541061c87021e6d93  f8bd3f2000c28c5342fedeb5e50f2e75
# 99999  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %% [markdown]
# ## Check for duplicates in order_reviews

# %%
order_reviews_df[order_reviews_df.order_id.duplicated()].sort_values('order_id').reset_index(drop=True)
# Out:
#                             review_id                          order_id  \
# 0    89a02c45c340aeeb1354a24e7d4b2c1e  0035246a40f520710769010f752e7507
# 1    73413b847f63e02bc752b364f6d05ee9  013056cfe49763c6f66bda03396c5ee3
# 2    d8e8c42271c8fb67b9dad95d98c8ff80  0176a6846bcb3b0d3aa3116a9a768597
# 3    0c8e7347f1cdd2aede37371543e3d163  02355020fd0a40a0d56df9f6ff060413
# 4    61fe4e7d1ae801bbe169eb67b86c6eda  029863af4b968de1e5d6a82782e662f5
# ..                                ...                               ...
# 554  c509f8b367ee5227700c29fcc76a097a  fd95ae805c63c534f1a64589e102225e
# 555  9da0796858da97acd8b67578388a3241  fe041ba1c9f54016432fa6ee91709dbc
# 556  c56a88a404315a0d9e412c1472dda2c4  ff763b73e473d03c321bcd5a053316e8
# 557  39de8ad3a1a494fc68cc2d5382f052f4  ff850ba359507b996e8b2fbb26df8d03
# 558  870d856a4873d3a67252b0c51d79b950  ffaabba06c9d293a3c614e0515ddbabc
#
#      review_score review_comment_title  \
# 0               5                  NaN
# ...

# %% [markdown]
# #### There are duplicate in the order reviews, let's explore more to confirm

# %%
order_reviews_df[order_reviews_df.order_id=='0035246a40f520710769010f752e7507']
# Out:
#                               review_id                          order_id  \
# 22585  2a74b0559eb58fc1ff842ecc999594cb  0035246a40f520710769010f752e7507
# 25802  89a02c45c340aeeb1354a24e7d4b2c1e  0035246a40f520710769010f752e7507
#
#        review_score review_comment_title  \
# 22585             5                  NaN
# 25802             5                  NaN
#
#                                   review_comment_message review_creation_date  \
# 22585  Estou acostumada a comprar produtos pelo barat...  2017-08-25 00:00:00
# 25802                                                NaN  2017-08-29 00:00:00
#
#       review_answer_timestamp
# 22585     2017-08-29 21:45:57
# 25802     2017-08-30 01:59:12

# %% [markdown]
# #### We have instances of more than one review for one order, let's try to get more info

# %%
order_reviews_df.order_id.value_counts()
# Out:
# 03c939fd7fd3b38f8485a0f95798f1f6    3
# df56136b8031ecd28e200bb18e6ddb2e    3
# c88b1d1b157a9999ce368f218a407141    3
# 8e17072ec97ce29f0e1f111e598b0c85    3
# 8ef17147aad160f7780239dcf0acb400    2
#                                    ..
# 00a250dbdb3153cc6ecf4d3f07ef6a17    1
# 9996aad294da648f199033d51534f004    1
# 5837a2c844decae8a778657425f6d664    1
# 5e82591b43cb83a7dd419ff564e44d04    1
# 90531360ecb1eec2a1fbb265a0db0508    1
# Name: order_id, Length: 99441, dtype: int64

# %% [markdown]
# #### So it's confirmed. Order_id repeats itself

# %% [markdown]
# ## Make a new dataframe shrinked_order_review  with data from order_reviews_df but grouped so as it contains one order_id and the others put in a list aside review_score which we find their mean since its the only column with numeric data type

# %%
shrinked_order_reviews_df=order_reviews_df.groupby('order_id').agg({'review_score':'mean',  'review_id': lambda x:list(x),
                                         'review_comment_title': lambda x:list(x),
                                         'review_comment_message': lambda x:list(x),
                                         'review_creation_date': lambda x:list(x),
                                         'review_answer_timestamp': lambda x:list(x)}).reset_index()
shrinked_order_reviews_df
# Out:
#                                order_id  review_score  \
# 0      00010242fe8c5a6d1ba2dd792cb16214           5.0
# 1      00018f77f2f0320c557190d7a144bdd3           4.0
# 2      000229ec398224ef6ca0657da4fc703e           5.0
# 3      00024acbcdf0a6daa1e931b038114c75           4.0
# 4      00042b26cf59d7ce69dfabb4e55b4fd9           5.0
# ...                                 ...           ...
# 99436  fffc94f6ce00a00581880bf54a75a037           5.0
# 99437  fffcd46ef2263f404302a634eb57f7eb           5.0
# 99438  fffce4705a9662cd70adb13d4a31832d           5.0
# 99439  fffe18544ffabc95dfada21779c9644f           5.0
# 99440  fffe41c64501cc87c801fd61db3f6244           5.0
#
#                                 review_id review_comment_title  \
# 0      [97ca439bc427b48bc1cd7177abe71365]                [nan]
# 1      [7b07bacd811c4117b742569b04ce3580]                [nan]
# 2      [0c5b33dea94867d1ac402749e5438e8b]                [nan]
# ...

# %% [markdown]
# ## merge data and shrinked_order_review

# %%
data=data.merge(shrinked_order_reviews_df,on='order_id',how='left')
data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %% [markdown]
# ## Check for missing values in data

# %%
data.isnull().sum()
# Out:
# order_id                            0
# payment_sequential                  0
# payment_type                        0
# payment_installments                0
# payment_value                       0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 175
# order_delivered_carrier_date     1888
# order_delivered_customer_date    3132
# order_estimated_delivery_date       0
# order_item_id                     830
# product_id                        830
# seller_id                         830
# shipping_limit_date               830
# price                             830
# freight_value                     830
# product_category_name            2331
# product_name_lenght              2331
# product_description_lenght       2331
# product_photos_qty               2331
# product_weight_g                  848
# product_length_cm                 848
# product_height_cm                 848
# ...

# %% [markdown]
# #### no missing values added but we should note that it's because of the list, there are alot of missing value enclosed by list, it's something we should put in mind incase we'd be working with them in future questions

# %% [markdown]
# ## Group seller by review_score

# %%
data[['review_score','seller_id']].groupby('review_score').count()
# Out:
#               seller_id
# review_score
# 1.000000          11713
# 1.500000              8
# 2.000000           3311
# 2.500000             38
# 3.000000           8560
# 3.333333              1
# 3.500000             26
# 4.000000          19891
# 4.333333              1
# 4.500000             66
# 5.000000          59441

# %% [markdown]
# #### Review score now has decimal, it is because of the mean in agg function, let's round the review_score column

# %%
data['review_score']=data['review_score'].round()

# %% [markdown]
# ## Let's regroup again to see

# %%
seller_review=data[['review_score','seller_id']].groupby('review_score').count()
seller_review.reset_index(inplace=True)
seller_review
# Out:
#    review_score  seller_id
# 0           1.0      11713
# 1           2.0       3357
# 2           3.0       8561
# 3           4.0      19984
# 4           5.0      59441

# %% [markdown]
# ## Make a plot to visualise it

# %%
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(8,4))
ax[0].pie(seller_review['seller_id'],autopct='%.1f%%')
ax[0].set_title('Rating Distrution')
ax[0].legend(title='Review Score', labels=seller_review['review_score'],bbox_to_anchor=(1,1))

ax[1].bar(seller_review['review_score'],seller_review['seller_id'])
ax[1].set_ylabel('No of Sales')
ax[1].set_xlabel('Review Score')
ax[1].set_title('Amount of Sale per review')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7: How many customers have made repeat purchases on Olist, and what percentage of total sales do they account for?

# %%
data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %% [markdown]
# ## Group data by customer_id getting the number of times a customer purchase and the total money spent

# %%
customer_purchase=data[['customer_id','payment_type','payment_value']].groupby('customer_id').agg({'payment_type':'count','payment_value':'sum'}).reset_index()
customer_purchase.rename(columns={'payment_type':'number_of_purchase','payment_value':'total_payment'},inplace=True)

# %%
customer_purchase
# Out:
#                             customer_id  number_of_purchase  total_payment
# 0      00012a2ce6f8dcda20d059ce98491703                   1         114.74
# 1      000161a058600d5901f007fab4c27140                   1          67.41
# 2      0001fd6190edaaf884bcaf3d49edf079                   1         195.42
# 3      0002414f95344307404f0ace7a26f1d5                   1         179.35
# 4      000379cdec625522490c315e70c7a9fb                   1         107.01
# ...                                 ...                 ...            ...
# 99435  fffecc9f79fd8c764f843e9951b11341                   3          81.36
# 99436  fffeda5b6d849fbd39689bb92087f431                   1          63.13
# 99437  ffff42319e9b2d713724ae527742af25                   1         214.13
# 99438  ffffa3172527f765de70084a7e53aae8                   1          45.50
# 99439  ffffe8b65bbe3087b653a978c870db99                   1          18.37
#
# [99440 rows x 3 columns]

# %% [markdown]
# ## Get customers that has made more than one purchase

# %%
repeated_purchase=customer_purchase[customer_purchase.number_of_purchase>1].reset_index(drop=True)
repeated_purchase
# Out:
#                            customer_id  number_of_purchase  total_payment
# 0     000e943451fc2788ca6ac98a682f2f49                   4         106.23
# 1     001051abfcfdbed9f87b4266213a5df1                   3          65.20
# 2     004937d0f9d6ce15c2830c00c2f482e5                   2          70.91
# 3     0049e8442c2a3e4a8d1ff5a9549abd53                   2        1250.81
# 4     006a5d6b5f648f3811fd4fa94d93a67c                   2          76.94
# ...                                ...                 ...            ...
# 2956  ff4512b27e3f8d9774f6e01ceb951035                   2         150.64
# 2957  ff7b32d3da9ed589c9695bc56021b10d                   4         142.33
# 2958  ffbf82fe167e7156e06fc1778d6b1cea                   3         118.23
# 2959  fff3a5c6d542d52b05f7e4518adf996e                   3          83.23
# 2960  fffecc9f79fd8c764f843e9951b11341                   3          81.36
#
# [2961 rows x 3 columns]

# %% [markdown]
# ##  get the sum of customers that have made repeated purchase

# %%
f'{len(repeated_purchase)} customers have made repeated purchases'
# Out:
# '2961 customers have made repeated purchases'

# %% [markdown]
# ## get the percentage of customers that made repeated purchase

# %%
f'{round((repeated_purchase.total_payment.sum()/customer_purchase.total_payment.sum())*100,2)}% \
of sales are from customers with repeated purchase'
# Out:
# '3.07% of sales are from customers with repeated purchase'

# %% [markdown]
# ## Visualisation

# %%
plt.pie(x=[repeated_purchase.total_payment.sum(),customer_purchase.total_payment.sum()-repeated_purchase.total_payment.sum()]\
          ,autopct='%.2f%%',labels=['Repeated Purchase','Non Repeated Purchase'])
plt.title('Distribution of Repeated Customers')
plt.show()

# %% [markdown]
# ## 8: What is the average customer rating for products sold on Olist, and how does this impact sales performance?

# %%
data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %% [markdown]
# ## Get the average review score

# %%
f'The average review score is {data.review_score.mean()}'
# Out:
# 'The average review score is 4.068729183913136'

# %% [markdown]
# #### The average review score is 4, it is okay! but it can also serve as a major drawback if competitors are giving better service than us. we should improve our services to the customers

# %% [markdown]
# ## Check correlation coefficient between review score and sales

# %%
np.corrcoef(data.review_score,data.payment_value)[0,1]
# Out:
# -0.04781310547355054

# %% [markdown]
# #### The correlation coefficient is -0.05, this implies that there is a degree of relationship between review_score and payment value though it is very small.

# %% [markdown]
# ## 9: What is the average order cancellation rate on Olist, and how does this impact seller performance?.

# %%
data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %% [markdown]
# ## Count each order status in data

# %%
status_summary=data.order_status.value_counts()
status_summary
# Out:
# delivered      100756
# shipped          1166
# canceled          664
# unavailable       649
# invoiced          325
# processing        319
# created             5
# approved            2
# Name: order_status, dtype: int64

# %% [markdown]
# ## Calculate the cancellation percent

# %%
f' The cancellation rate on Olist is {round((status_summary.canceled/status_summary.sum())*100,2)}%'
# Out:
# ' The cancellation rate on Olist is 0.64%'

# %% [markdown]
# ## 10: What are the top-selling products on Olist, and how have their sales trends changed over time?

# %%
data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %% [markdown]
# ## Rank the popularity of the product category

# %%
product_popularity_ranking=data.product_category_name_english.value_counts().reset_index()

# %% [markdown]
# ## Get the top 5 product category

# %%
product_popularity_ranking.rename(columns={'index':'product_category'}, inplace=True)
top_selling=product_popularity_ranking[:5]
top_selling
# Out:
#         product_category  product_category_name_english
# 0         bed_bath_table                           9899
# 1          health_beauty                           9076
# 2         sports_leisure                           7954
# 3  computers_accessories                           6889
# 4        furniture_decor                           6691

# %% [markdown]
# ## Get the data containing the top 5 product category

# %%
top_selling_data=data[data.product_category_name_english.isin(top_selling.product_category)].reset_index(drop=True)
top_selling_data
# Out:
#                                order_id  payment_sequential payment_type  \
# 0      ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 1      42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# 2      298fcdf1f73eb413e4d26d01b25bc1cd                   1  credit_card
# 3      d88e0d5fa41661ce03cf6cf336527646                   1  credit_card
# 4      769214176682788a92801d8907fa1b40                   1  credit_card
# ...                                 ...                 ...          ...
# 40504  d41f1036712e18ee525939d08b7a1c98                   1  credit_card
# 40505  60aed0a4eba0e424eb3cac85017fd752                   1  credit_card
# 40506  0872d0faafe0cb56e6f2c594cca1522c                   1  credit_card
# 40507  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 40508  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#        payment_installments  payment_value                       customer_id  \
# ...

# %% [markdown]
# ## Group the top 5 by monthly breakdown

# %%
monthly_breakdown_top_selling=top_selling_data.groupby(['product_category_name_english',pd.Grouper(key='order_purchase_timestamp',freq='MS')]).sum()['payment_value']
monthly_breakdown_top_selling
# Out:
# product_category_name_english  order_purchase_timestamp
# bed_bath_table                 2016-10-01                   1094.63
#                                2017-01-01                   5091.50
#                                2017-02-01                  19098.23
#                                2017-03-01                  30906.54
#                                2017-04-01                  29149.91
#                                                              ...
# sports_leisure                 2018-04-01                  79028.79
#                                2018-05-01                  68615.28
#                                2018-06-01                  54646.15
#                                2018-07-01                  65410.16
#                                2018-08-01                  60345.24
# Name: payment_value, Length: 106, dtype: float64

# %% [markdown]
# ## Get the list for the top 5 product name

# %%
top_product=monthly_breakdown_top_selling.index.levels[0]

# %% [markdown]
# ## Plot of top 5 selling product trend over time

# %%
fig=plt.figure(figsize=(12,15))


ncols=1
nrows=len(top_product)//ncols+(len(top_product)%ncols>0)

  
for n, product in enumerate(top_product):
    ax=plt.subplot(nrows,ncols,n+1)
    
    monthly_breakdown_top_selling[product].plot(ax=ax,marker='o')
    
    ax.set_title(product)
    
    ax.set_xlabel('Year and Month')
    
    ax.set_ylabel('No. of sales')
    
    
plt.tight_layout()
plt.suptitle('Top 5 Selling Product',size=20,x=0.5,y=1.02)
plt.show()

# %% [markdown]
# ## 11: Which payment methods are most commonly used by Olist customers, and how does this vary by product category or geographic region?

# %%
data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %% [markdown]
# ## group by payment method and product category

# %%
payment_product_frequency=data.groupby(['product_category_name_english','payment_type']).count()['order_id']
categories=payment_product_frequency.index.levels[0]
total=len(payment_product_frequency.index.levels[0])
payment_product_frequency
# Out:
# product_category_name_english  payment_type
# agro_industry_and_commerce     boleto            51
#                                credit_card      125
#                                debit_card         4
#                                voucher           31
# air_conditioning               boleto            54
#                                                ...
# toys                           voucher          186
# watches_gifts                  boleto           916
#                                credit_card     4581
#                                debit_card        58
#                                voucher          250
# Name: order_id, Length: 262, dtype: int64

# %% [markdown]
# ## Make plots for each category with payment type adopted

# %%
fig=plt.figure(figsize=(15,60))

ncols=3
nrows=total//ncols+(total%ncols>0)


  
for n, category in enumerate(categories):
    ax=plt.subplot(nrows,ncols,n+1)
    
    payment_product_frequency[category].plot(ax=ax)
    
    ax.set_title(category)
    
    ax.set_xlabel('Payment Type')
    ax.set_ylabel('No. of sales')

plt.tight_layout()
plt.suptitle('Payment Type per Category',y=1.01,size=20)

plt.show()

# %% [markdown]
# ## 12: How do customer reviews and ratings affect sales and product performance on Olist?

# %%
data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %% [markdown]
# ## Show plot from question 7.

# %%
plt.bar(seller_review['review_score'],seller_review['seller_id'])
plt.ylabel('No of Sales')
plt.xlabel('Review Score')
plt.title('Sales')
plt.show()

# %% [markdown]
# ### From the plot, product with higher review score were the once with highest number of sales and vice versa.

# %% [markdown]
# ## 13: Which product categories have the highest profit margins on Olist, and how can the company increase profitability across different categories?

# %%
data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %% [markdown]
# ### There is no sufficient information showing profit made, so profit margin can't be calculated, let's consider product category that generates the highest revenue instead

# %% [markdown]
# ## Get revenue generated from each product category

# %%
revenue_by_category=data[['product_category_name_english','payment_value']].groupby('product_category_name_english').sum()\
.sort_values('payment_value', ascending=False)
revenue_by_category.rename({'payment_value':'revenue'}, axis=1,inplace=True)
revenue_by_category
# Out:
#                                   revenue
# product_category_name_english
# health_beauty                  1439926.41
# watches_gifts                  1303159.52
# bed_bath_table                 1240930.24
# sports_leisure                 1157754.33
# computers_accessories          1057630.10
# ...                                   ...
# flowers                           1794.87
# home_comfort_2                    1131.41
# cds_dvds_musicals                  954.99
# fashion_childrens_clothes          785.67
# security_and_services              324.51
#
# [71 rows x 1 columns]

# %% [markdown]
# ## Make a plot for the top ten product category

# %%
plt.barh(revenue_by_category.index[:10],revenue_by_category.revenue[:10])

plt.title('Product Category with Highest Revenue')
plt.xlabel('Product Category')
plt.ylabel('Revenue(Millions)')

plt.show()

# %% [markdown]
# ## 14: How does Olist's marketing spend and channel mix impact sales and customer acquisition costs, and how can the company optimize its marketing strategy to increase ROI?

# %% [markdown]
# ## 15: Geolocation having high customer density. Calculate customer retention rate according to geolocations.

# %%
data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %% [markdown]
# #### Insufficient data to answer the question

# %% [markdown]
# ## Explore more dataset that was previously loaded

# %%
customers_df
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %% [markdown]
# ## A dictionary that maps abbreviation of the states to their name

# %%
state_conversion={'AC':'Acre','AL':'Alagoas','AP':'Amapa','AM':'Amazonas','BA':'Bahia','CE':'Ceara',
                 'DF':'Distrito Federal','ES':'Espirito Santo','GO':'Goias','MA':'Maranhao','MT':'Mato Grosso',
                 'PE':'Pernambuco','MS':'Mato Grosso do Sul','MG':'Minas Gerais','PA':'para','PR':'parana','PB':'Paraiba',
                 'PI':'Piaui','RR':'Roraima','RO':'Rondonia','RJ':'Rio de Janeiro','RN':'Rio Grande do Norte',
                 'RS':'Rio Grande do Sul','SC':'Santa Catarina','SP':'Sao Paulo','SE':'Sergipe','TO':'Tocantins'}

# %% [markdown]
# ## change the abbreviation to the normal name in customer state

# %%
def convert_state(state):
    return state_conversion[state]
customers_df['customer_state']=customers_df['customer_state'].apply(convert_state)

# %% [markdown]
# ### This contain the necessary information

# %% [markdown]
# ## Get amount of customer per city

# %%
customers_per_city=customers_df[['customer_id','customer_state']].groupby('customer_state').count()\
.sort_values('customer_id',ascending=False).reset_index()
customers_per_state=customers_per_city.rename({'customer_state':'state','customer_id':'no. of customers'}, axis=1)
customers_per_state
# Out:
#                   state  no. of customers
# 0             Sao Paulo             41746
# 1        Rio de Janeiro             12852
# 2          Minas Gerais             11635
# 3     Rio Grande do Sul              5466
# 4                parana              5045
# 5        Santa Catarina              3637
# 6                 Bahia              3380
# 7      Distrito Federal              2140
# 8        Espirito Santo              2033
# 9                 Goias              2020
# 10           Pernambuco              1652
# 11                Ceara              1336
# 12                 para               975
# 13          Mato Grosso               907
# 14             Maranhao               747
# 15   Mato Grosso do Sul               715
# 16              Paraiba               536
# 17                Piaui               495
# 18  Rio Grande do Norte               485
# 19              Alagoas               413
# 20              Sergipe               350
# ...

# %% [markdown]
# ## Make a plot for the top 10 states with highest customer density

# %%
plt.barh(customers_per_state.state[:10],customers_per_state['no. of customers'][:10])
plt.title('Top 10 States With Highest Customer Density')
plt.xlabel('State')
plt.ylabel('No. of customer')
plt.show()

# %% [markdown]
# ## Merge data with customer_df

# %%
data=data.merge(customers_df, on='customer_id')
data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %% [markdown]
# ## Check for missing values after merging

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103886 entries, 0 to 103885
# Data columns (total 37 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       103886 non-null  object
#  1   payment_sequential             103886 non-null  int64
#  2   payment_type                   103886 non-null  object
#  3   payment_installments           103886 non-null  int64
#  4   payment_value                  103886 non-null  float64
#  5   customer_id                    103886 non-null  object
#  6   order_status                   103886 non-null  object
#  7   order_purchase_timestamp       103886 non-null  datetime64[ns]
#  8   order_approved_at              103711 non-null  datetime64[ns]
#  9   order_delivered_carrier_date   101998 non-null  datetime64[ns]
#  10  order_delivered_customer_date  100754 non-null  datetime64[ns]
# ...

# %% [markdown]
# ## Get number of total purchase for each customer in each state

# %%
customer_state_details=data[['customer_state','customer_id','order_id']].groupby(['customer_state','customer_id']).count()
customer_state_details
# Out:
#                                                  order_id
# customer_state customer_id
# Acre           013bdb994a9c8f09fde3f5f543e698ad         1
#                061a531d906f4bfb762be36757e41f7b         1
#                08420efd8b1c0be27393032e21a993ee         1
#                0f32385df13e46d88d997460208bc866         1
#                10ad09201fcc1c82d181ff7234bcdb3b         1
# ...                                                   ...
# parana         ffbc52ac99e6184f3961fd791be5ff62         1
#                ffcbcec4480d074ffd50398e66bff27c         1
#                ffd940dedc35e4f459eddfa41291e824         1
#                ffe509f377a33554f5a677dcd83e669e         1
#                ffed827348cd4b083956ce2b634b763b         1
#
# [99440 rows x 1 columns]

# %% [markdown]
# ## Calculate the retention rate for each city

# %%
retention_rate={}
for state in customer_state_details.index.unique('customer_state'):
    retained=(customer_state_details.loc[state]>1)['order_id'].sum()
    total=len(customer_state_details.loc[state])
    
    retention_rate[state]=100*retained/total

retention_rate
# Out:
# {'Acre': 3.7037037037037037,
#  'Alagoas': 2.9055690072639226,
#  'Amapa': 2.9411764705882355,
#  'Amazonas': 2.7027027027027026,
#  'Bahia': 4.5266272189349115,
#  'Ceara': 3.44311377245509,
#  'Distrito Federal': 2.710280373831776,
#  'Espirito Santo': 2.9021151008362027,
#  'Goias': 2.9207920792079207,
#  'Maranhao': 2.2757697456492636,
#  'Mato Grosso': 2.4255788313120177,
#  'Mato Grosso do Sul': 2.237762237762238,
#  'Minas Gerais': 2.9909755049419853,
#  'Paraiba': 4.850746268656716,
#  'Pernambuco': 3.5714285714285716,
#  'Piaui': 5.656565656565657,
#  'Rio Grande do Norte': 4.123711340206185,
#  'Rio Grande do Sul': 2.6527625320160997,
#  'Rio de Janeiro': 3.1901649548708373,
#  'Rondonia': 2.766798418972332,
#  'Roraima': 0.0,
#  'Santa Catarina': 2.722023645861974,
#  'Sao Paulo': 2.807521858905258,
#  'Sergipe': 2.857142857142857,
#  'Tocantins': 3.2142857142857144,
#  'para': 3.1794871794871793,
#  'parana': 2.8939544103072348}

# %% [markdown]
# ## convert the returned dictionary into a dataframe

# %%
retention_rate_df=pd.DataFrame.from_dict(retention_rate, orient='index')
retention_rate_df=retention_rate_df.rename({0:'retention_rate'},axis=1)
retention_rate_df
# Out:
#                      retention_rate
# Acre                       3.703704
# Alagoas                    2.905569
# Amapa                      2.941176
# Amazonas                   2.702703
# Bahia                      4.526627
# Ceara                      3.443114
# Distrito Federal           2.710280
# Espirito Santo             2.902115
# Goias                      2.920792
# Maranhao                   2.275770
# Mato Grosso                2.425579
# Mato Grosso do Sul         2.237762
# Minas Gerais               2.990976
# Paraiba                    4.850746
# Pernambuco                 3.571429
# Piaui                      5.656566
# Rio Grande do Norte        4.123711
# Rio Grande do Sul          2.652763
# Rio de Janeiro             3.190165
# Rondonia                   2.766798
# Roraima                    0.000000
# Santa Catarina             2.722024
# Sao Paulo                  2.807522
# Sergipe                    2.857143
# Tocantins                  3.214286
# ...

# %% [markdown]
# ## Sort the values

# %%
retention_rate_df.sort_values('retention_rate',ascending=False)[:20]
# Out:
#                      retention_rate
# Piaui                      5.656566
# Paraiba                    4.850746
# Bahia                      4.526627
# Rio Grande do Norte        4.123711
# Acre                       3.703704
# Pernambuco                 3.571429
# Ceara                      3.443114
# Tocantins                  3.214286
# Rio de Janeiro             3.190165
# para                       3.179487
# Minas Gerais               2.990976
# Amapa                      2.941176
# Goias                      2.920792
# Alagoas                    2.905569
# Espirito Santo             2.902115
# parana                     2.893954
# Sergipe                    2.857143
# Sao Paulo                  2.807522
# Rondonia                   2.766798
# Santa Catarina             2.722024

# %%
plt.bar(retention_rate_df.index, retention_rate_df.retention_rate)
plt.title('Customer Retention Rate')
plt.xlabel('State')
plt.xticks(rotation=90)
plt.ylabel('Retention Rate(%)')

plt.show()
